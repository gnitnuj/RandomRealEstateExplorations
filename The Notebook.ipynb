# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('Zip_Zhvi_SingleFamilyResidence.csv')

# %% [markdown]
# ### Basic EDA

# %%
# check out columns
df.columns
# Out:
# Index([u'RegionID', u'RegionName', u'City', u'State', u'Metro', u'CountyName',
#        u'SizeRank', u'1996-04', u'1996-05', u'1996-06',
#        ...
#        u'2015-06', u'2015-07', u'2015-08', u'2015-09', u'2015-10', u'2015-11',
#        u'2015-12', u'2016-01', u'2016-02', u'2016-03'],
#       dtype='object', length=247)

# %%
# check out what the data looks like
df.head()
# Out:
#    RegionID  RegionName     City State    Metro CountyName  SizeRank  1996-04  \
# 0     84654       60657  Chicago    IL  Chicago       Cook         1   413300
# 1     84616       60614  Chicago    IL  Chicago       Cook         2   532800
# 2     93144       79936  El Paso    TX  El Paso    El Paso         3    70900
# 3     91733       77084  Houston    TX  Houston     Harris         4    76700
# 4     84640       60640  Chicago    IL  Chicago       Cook         5   293000
#
#    1996-05  1996-06   ...     2015-06  2015-07  2015-08  2015-09  2015-10  \
# 0   415800   418200   ...     1049100  1052500  1055600  1059200  1059100
# 1   536700   541400   ...     1486900  1508600  1526500  1533000  1527500
# 2    71200    71100   ...      111500   111900   112000   111600   111200
# 3    76500    76000   ...      144700   145900   146900   147400   147500
# 4   292000   289700   ...      719100   718800   715600   711300   709200
#
#    2015-11  2015-12  2016-01  2016-02  2016-03
# ...

# %%
# check out shape
df.shape
# Out:
# (13197, 247)

# %%
# describe data to get some general statistical data
df.describe()
# Out:
#             RegionID    RegionName      SizeRank         1996-04  \
# count   13197.000000  13197.000000  13197.000000    10550.000000
# mean    80382.924074  46385.109419   6599.000000   124203.668246
# std     32289.050361  30055.825399   3809.790086    79862.198152
# min     58196.000000   1001.000000      1.000000    29200.000000
# 25%     66242.000000  20119.000000   3300.000000    75800.000000
# 50%     76712.000000  43231.000000   6599.000000   105200.000000
# 75%     90710.000000  75040.000000   9898.000000   148675.000000
# max    738092.000000  99901.000000  13197.000000  1762300.000000
#
#               1996-05         1996-06         1996-07         1996-08  \
# count    10691.000000    10730.000000    10736.000000    10749.000000
# mean    124148.592274   124118.061510   124153.334575   124204.028282
# std      79373.557547    79252.130391    79221.952270    79147.194877
# min      28800.000000    28500.000000    28500.000000    28400.000000
# ...

# %% [markdown]
# The data actually looks pretty clean, which is awesome. There do seem to be some indications of missing data looking at the counts. Still not quite sure what SizeRank represent, might just drop the column. The housing prices go up over time from what I can tell which makes sense. Doesn't look like the values have been taken inflation into account, which is fine.

# %%
# explore nulls
df.isnull().any()
# Out:
# RegionID      False
# RegionName    False
# City          False
# State         False
# Metro          True
# CountyName    False
# SizeRank      False
# 1996-04        True
# 1996-05        True
# 1996-06        True
# 1996-07        True
# 1996-08        True
# 1996-09        True
# 1996-10        True
# 1996-11        True
# 1996-12        True
# 1997-01        True
# 1997-02        True
# 1997-03        True
# 1997-04        True
# 1997-05        True
# 1997-06        True
# 1997-07        True
# 1997-08        True
# 1997-09        True
# 1997-10        True
# 1997-11        True
# 1997-12        True
# 1998-01        True
# 1998-02        True
#               ...
# 2013-10       False
# 2013-11       False
# 2013-12       False
# 2014-01       False
# 2014-02       False
# 2014-03       False
# 2014-04        True
# 2014-05        True
# 2014-06       False
# 2014-07        True
# 2014-08       False
# 2014-09       False
# 2014-10       False
# 2014-11       False
# ...

# %% [markdown]
# hmmmm didn't get to see all columns since there are way too many, but it looks like there are only 7 non date/time related columns.

# %%
# %matplotlib inline

# %%
df.plot()

# %% [markdown]
# yeah... figured that one wouldn't go too well.
#
# anyways let's get back to handling those null values!

# %% [markdown]
# ### Data Preparation

# %%
# fill only category with missing data
df["Metro"].fillna('missing', inplace=True)
#  double check that i got them all
df['Metro'].isnull().any()
# Out:
# False

# %%
# get a rough estimate of the sum of missing values per column
pd.isnull(df).sum()
# Out:
# RegionID         0
# RegionName       0
# City             0
# State            0
# Metro            0
# CountyName       0
# SizeRank         0
# 1996-04       2647
# 1996-05       2506
# 1996-06       2467
# 1996-07       2461
# 1996-08       2448
# 1996-09       2448
# 1996-10       2448
# 1996-11       2440
# 1996-12       2440
# 1997-01       2335
# 1997-02       1714
# 1997-03       1625
# 1997-04       1625
# 1997-05       1624
# 1997-06       1623
# 1997-07       1623
# 1997-08       1499
# 1997-09       1496
# 1997-10       1494
# 1997-11       1478
# 1997-12       1470
# 1998-01       1438
# 1998-02       1324
#               ...
# 2013-10          0
# 2013-11          0
# 2013-12          0
# 2014-01          0
# 2014-02          0
# 2014-03          0
# 2014-04          2
# 2014-05          2
# 2014-06          0
# 2014-07          2
# 2014-08          0
# 2014-09          0
# 2014-10          0
# 2014-11          0
# 2014-12          0
# 2015-01          0
# ...

# %%
# select last 240 columns (ignore first 7 because they are categorical)
df.iloc[:,-240:].head()
# Out:
#    1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  1996-10  1996-11  \
# 0   413300   415800   418200   420200   421100   423400   427500   426600
# 1   532800   536700   541400   554000   562600   569700   579400   579100
# 2    70900    71200    71100    71300    71400    71900    72700    73100
# 3    76700    76500    76000    75800    75700    75600    75700    75900
# 4   293000   292000   289700   288800   289700   290400   290200   288300
#
#    1996-12  1997-01   ...     2015-06  2015-07  2015-08  2015-09  2015-10  \
# 0   418400   412400   ...     1049100  1052500  1055600  1059200  1059100
# 1   568800   562600   ...     1486900  1508600  1526500  1533000  1527500
# 2    72700    72700   ...      111500   111900   112000   111600   111200
# 3    76100    76600   ...      144700   145900   146900   147400   147500
# 4   284800   281800   ...      719100   718800   715600   711300   709200
#
#    2015-11  2015-12  2016-01  2016-02  2016-03
# ...

# %%
# since 13k+ rows, but at most 2k-ish missing columns,
# filling the missing numerical values with means is probably okay
for column in df.iloc[:,-240:]:
    df[column].fillna(df[column].mean(), inplace=True)

# %%
# check is the filling with means worked
pd.isnull(df).sum()
# Out:
# RegionID      0
# RegionName    0
# City          0
# State         0
# Metro         0
# CountyName    0
# SizeRank      0
# 1996-04       0
# 1996-05       0
# 1996-06       0
# 1996-07       0
# 1996-08       0
# 1996-09       0
# 1996-10       0
# 1996-11       0
# 1996-12       0
# 1997-01       0
# 1997-02       0
# 1997-03       0
# 1997-04       0
# 1997-05       0
# 1997-06       0
# 1997-07       0
# 1997-08       0
# 1997-09       0
# 1997-10       0
# 1997-11       0
# 1997-12       0
# 1998-01       0
# 1998-02       0
#              ..
# 2013-10       0
# 2013-11       0
# 2013-12       0
# 2014-01       0
# 2014-02       0
# 2014-03       0
# 2014-04       0
# 2014-05       0
# 2014-06       0
# 2014-07       0
# 2014-08       0
# 2014-09       0
# 2014-10       0
# 2014-11       0
# 2014-12       0
# 2015-01       0
# 2015-02       0
# 2015-03       0
# 2015-04       0
# 2015-05       0
# 2015-06       0
# 2015-07       0
# 2015-08       0
# 2015-09       0
# ...

# %%
df.head()
# Out:
#    RegionID  RegionName     City State    Metro CountyName  SizeRank  1996-04  \
# 0     84654       60657  Chicago    IL  Chicago       Cook         1   413300
# 1     84616       60614  Chicago    IL  Chicago       Cook         2   532800
# 2     93144       79936  El Paso    TX  El Paso    El Paso         3    70900
# 3     91733       77084  Houston    TX  Houston     Harris         4    76700
# 4     84640       60640  Chicago    IL  Chicago       Cook         5   293000
#
#    1996-05  1996-06   ...     2015-06  2015-07  2015-08  2015-09  2015-10  \
# 0   415800   418200   ...     1049100  1052500  1055600  1059200  1059100
# 1   536700   541400   ...     1486900  1508600  1526500  1533000  1527500
# 2    71200    71100   ...      111500   111900   112000   111600   111200
# 3    76500    76000   ...      144700   145900   146900   147400   147500
# 4   292000   289700   ...      719100   718800   715600   711300   709200
#
#    2015-11  2015-12  2016-01  2016-02  2016-03
# ...

# %%
# kind of out of order but refer to the pearson correlation below as to why i dropped it.
df.drop(["SizeRank"], axis=1, inplace=True)

# %% [markdown]
# ### More Data Explorations

# %%
# get pearson correlation
pearson = df.corr(method='pearson')
pearson
# Out:
#             RegionID  RegionName   1996-04   1996-05   1996-06   1996-07  \
# RegionID    1.000000    0.457928  0.036659  0.037764  0.038235  0.038267
# RegionName  0.457928    1.000000  0.086654  0.086876  0.087227  0.087280
# 1996-04     0.036659    0.086654  1.000000  0.997995  0.996611  0.995663
# 1996-05     0.037764    0.086876  0.997995  1.000000  0.998997  0.998259
# 1996-06     0.038235    0.087227  0.996611  0.998997  1.000000  0.999554
# 1996-07     0.038267    0.087280  0.995663  0.998259  0.999554  1.000000
# 1996-08     0.038548    0.087989  0.994998  0.997713  0.999163  0.999831
# 1996-09     0.038956    0.089167  0.994492  0.997279  0.998799  0.999571
# 1996-10     0.039501    0.090593  0.994008  0.996850  0.998422  0.999253
# 1996-11     0.040233    0.092286  0.993327  0.996234  0.997853  0.998733
# 1996-12     0.040967    0.093908  0.992842  0.995802  0.997450  0.998362
# 1997-01     0.040664    0.092883  0.990722  0.993767  0.995475  0.996437
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Time Series Analysis

# %% [markdown]
# Well... since the data is pretty much a time series, let's see what I can do to work with it.
#
# At this point, I thought to myself, maybe I should get a different dataset with more independent variables, and just start over, but then I looked into the what I can do with machine learning techniques and time series data and found it that it was possible to forecast a time series!
#
# http://www.analyticsvidhya.com/blog/2015/12/complete-tutorial-time-series-modeling/ was a really good read.
#
# Sounds a bit complicated, but I'm hoping to be able to work through a forecast of a time series.

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
# copy over just the relevant time series data

# %%
ts_data = df.copy()

# %%
# lets only work with the data from one zip code
# 90062 is the zip code of the house im in escrow on :)
ts_data = ts_data[ts_data.RegionName.isin([90062])]
ts_data
# Out:
#       RegionID  RegionName         City State  \
# 4402     96043       90062  Los Angeles    CA
#
#                                    Metro   CountyName  1996-04  1996-05  \
# 4402  Los Angeles-Long Beach-Anaheim, CA  Los Angeles   119700   121200
#
#       1996-06  1996-07   ...     2015-06  2015-07  2015-08  2015-09  2015-10  \
# 4402   122200   122300   ...      379800   382700   383800   384300   384700
#
#       2015-11  2015-12  2016-01  2016-02  2016-03
# 4402   384700   385400   386800   388300   389400
#
# [1 rows x 246 columns]

# %%
# only work with time series data
ts_data = ts_data.iloc[:,-240:]
ts_data
# Out:
#       1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  1996-10  1996-11  \
# 4402   119700   121200   122200   122300   121900   121700   121500   121400
#
#       1996-12  1997-01   ...     2015-06  2015-07  2015-08  2015-09  2015-10  \
# 4402   121400   121700   ...      379800   382700   383800   384300   384700
#
#       2015-11  2015-12  2016-01  2016-02  2016-03
# 4402   384700   385400   386800   388300   389400
#
# [1 rows x 240 columns]

# %%
# tranpose the data
ts_data = ts_data.T
ts_data.head()
# Out:
#            4402
# 1996-04  119700
# 1996-05  121200
# 1996-06  122200
# 1996-07  122300
# 1996-08  121900

# %%
# rename 4402 to something more meaningful
ts_data.columns = ['Price']
ts_data.columns
# Out:
# Index([u'Price'], dtype='object')

# %%
# turn the index column into a date/time format
ts_data.index = pd.to_datetime(pd.Series(ts_data.index), format="%Y-%m")

# %%
ts_data.index
# Out:
# DatetimeIndex(['1996-04-01', '1996-05-01', '1996-06-01', '1996-07-01',
#                '1996-08-01', '1996-09-01', '1996-10-01', '1996-11-01',
#                '1996-12-01', '1997-01-01',
#                ...
#                '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01',
#                '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01',
#                '2016-02-01', '2016-03-01'],
#               dtype='datetime64[ns]', length=240, freq=None)

# %% [markdown]
# nice! that took wayyyy too long to figure out...
#
# let's practice with timeseries data...

# %%
ts_data['2016']
# Out:
#              Price
# 2016-01-01  386800
# 2016-02-01  388300
# 2016-03-01  389400

# %%
ts_data['2000':'2005']
# Out:
#              Price
# 2000-01-01  139500
# 2000-02-01  140500
# 2000-03-01  141100
# 2000-04-01  141100
# 2000-05-01  141600
# 2000-06-01  142700
# 2000-07-01  143800
# 2000-08-01  144400
# 2000-09-01  144800
# 2000-10-01  145300
# 2000-11-01  146600
# 2000-12-01  147800
# 2001-01-01  148800
# 2001-02-01  150200
# 2001-03-01  151500
# 2001-04-01  152600
# 2001-05-01  154100
# 2001-06-01  155900
# 2001-07-01  156900
# 2001-08-01  157300
# 2001-09-01  158000
# 2001-10-01  159200
# 2001-11-01  160400
# 2001-12-01  161900
# 2002-01-01  163800
# 2002-02-01  165700
# 2002-03-01  167000
# 2002-04-01  168400
# 2002-05-01  169600
# 2002-06-01  170500
# ...            ...
# 2003-07-01  213300
# 2003-08-01  217700
# 2003-09-01  220300
# 2003-10-01  223700
# 2003-11-01  229100
# 2003-12-01  236000
# 2004-01-01  243000
# 2004-02-01  249400
# 2004-03-01  254900
# 2004-04-01  260300
# 2004-05-01  265700
# 2004-06-01  271500
# 2004-07-01  278900
# 2004-08-01  288700
# 2004-09-01  298000
# ...

# %%
# graph of least resistance
plt.plot(ts_data)

# %% [markdown]
# exactly what we'd expect. steady increase, with houses peaking, before the recessions

# %%
#  courtesy of http://www.analyticsvidhya.com/
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print 'Results of Dickey-Fuller Test:'
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print dfoutput

# %% [markdown]
# #### so the idea behind test_stationarity is to compare p-value to the critical value. (more negative p than critical = more better, excuse the gammer)

# %%
test_stationarity(ts_data)
# Out:
# Results of Dickey-Fuller Test:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-47bdd67cb823> in <module>()
# ----> 1 test_stationarity(ts_data)
#
# <ipython-input-58-3db4204bf364> in test_stationarity(timeseries)
#      17     #Perform Dickey-Fuller test:
#      18     print 'Results of Dickey-Fuller Test:'
# ---> 19     dftest = adfuller(timeseries, autolag='AIC')
#      20     dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
#      21     for key,value in dftest[4].items():
#
# /Users/junting/anaconda/lib/python2.7/site-packages/statsmodels/tsa/stattools.pyc in adfuller(x, maxlag, regression, autolag, store, regresults)
#     209
#     210     xdiff = np.diff(x)
# --> 211     xdall = lagmat(xdiff[:, None], maxlag, trim='both', original='in')
# ...

# %% [markdown]
# think i am missing something minor with regards to input data... let's see if i can fix it.

# %%
ts_data[~ts_data.applymap(np.isreal).all(1)]
# Out:
# Empty DataFrame
# Columns: [Price]
# Index: []

# %%
# think i need to remove all the non data/integer cells
ts_data_2 = ts_data['Price']
ts_data_2.head()
# Out:
# 1996-04-01    119700
# 1996-05-01    121200
# 1996-06-01    122200
# 1996-07-01    122300
# 1996-08-01    121900
# Name: Price, dtype: float64

# %%
test_stationarity(ts_data_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.772749
# p-value                          0.394072
# #Lags Used                      14.000000
# Number of Observations Used    225.000000
# Critical Value (5%)             -2.874473
# Critical Value (1%)             -3.459752
# Critical Value (10%)            -2.573663
# dtype: float64

# %% [markdown]
# #### -1.772749 > -2.573663, so not that great(stationary). Less than 90% confidence that this is a stationary series

# %% [markdown]
# Obviously the data is not stationary probably because other than the recession there is an increase in home value over time.
#
# Really wish I had data farther back than 1996, possible back to 1950 or something. Anyways, I'll work with what I have, at least I have every months data for the last 20 years. :)
#
# So anyways the other reason it's not stationary is because of the recession. It really is an outlier no matter which way you look at it. Unless there were consistent somewhat predictable recessions in the past to work with, but I don't have that data.
#
# Random thought, it would be pretty cool to do a project with data back into prehistoric times, like the earths temperature and see if we can predict global warming or cooling patterns.

# %% [markdown]
# #### make data stationary so that we can make a model to forecast

# %%
# eliminate trend by tranforming data

# log?
ts_data_2_log = np.log(ts_data_2)
plt.plot(ts_data_2_log)

# %%
# check updated stationarity
test_stationarity(ts_data_2_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.780630
# p-value                          0.390120
# #Lags Used                      15.000000
# Number of Observations Used    224.000000
# Critical Value (5%)             -2.874531
# Critical Value (1%)             -3.459885
# Critical Value (10%)            -2.573694
# dtype: float64

# %% [markdown]
# #### -1.780630 > -2.573694, not much of an improvement over last. Less than 90% confidence that this is a stationary series

# %%
# the graph looks completely different, but the test statistic didn't change much, so i'd say there wasnt much improvement...

# %%
# use a rolling average to smooth the inconsistencies (recession pricing)

moving_avg = pd.rolling_mean(ts_data_2_log,12)
plt.plot(ts_data_2_log)
plt.plot(moving_avg, color='red')

# %%
test_stationarity(moving_avg)
# Out:
# Results of Dickey-Fuller Test:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-83-39222d42fbef> in <module>()
# ----> 1 test_stationarity(moving_avg)
#
# <ipython-input-63-3db4204bf364> in test_stationarity(timeseries)
#      17     #Perform Dickey-Fuller test:
#      18     print 'Results of Dickey-Fuller Test:'
# ---> 19     dftest = adfuller(timeseries, autolag='AIC')
#      20     dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
#      21     for key,value in dftest[4].items():
#
# /Users/junting/anaconda/lib/python2.7/site-packages/statsmodels/tsa/stattools.pyc in adfuller(x, maxlag, regression, autolag, store, regresults)
#     229         if not regresults:
#     230             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# ...

# %% [markdown]
# oops. looks like i passed some negative on NaNs, so it blew up.

# %%
# fix the above...

diff = ts_data_2_log - moving_avg
diff.head(12)
# Out:
# 1996-04-01        NaN
# 1996-05-01        NaN
# 1996-06-01        NaN
# 1996-07-01        NaN
# 1996-08-01        NaN
# 1996-09-01        NaN
# 1996-10-01        NaN
# 1996-11-01        NaN
# 1996-12-01        NaN
# 1997-01-01        NaN
# 1997-02-01        NaN
# 1997-03-01    0.01369
# Name: Price, dtype: float64

# %%
diff.dropna(inplace=True)
test_stationarity(diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.458235
# p-value                          0.125970
# #Lags Used                      13.000000
# Number of Observations Used    215.000000
# Critical Value (5%)             -2.875079
# Critical Value (1%)             -3.461136
# Critical Value (10%)            -2.573986
# dtype: float64

# %% [markdown]
# #### -2.458235 > -2.573986, really close but still less than 90% confidence that this is a stationary series

# %%
# weighted diff

weighted_diff = pd.ewma(ts_data_2_log, halflife=12)
plt.plot(ts_data_2_log)
plt.plot(weighted_diff, color='red')

# %%
test_stationarity(ts_data_2_log - weighted_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.659725
# p-value                          0.081271
# #Lags Used                      15.000000
# Number of Observations Used    224.000000
# Critical Value (5%)             -2.874531
# Critical Value (1%)             -3.459885
# Critical Value (10%)            -2.573694
# dtype: float64

# %% [markdown]
# #### -2.659725 < -2.573694, so finally I can say that I'm at least 90% confident that the series is stationary

# %% [markdown]
# #### decomposing

# %%
# credit to http://www.analyticsvidhya.com/
# the below breaks out trend and seasonality into seperate graphs so that it is easier to see their effects

from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_data_2_log)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# this exact graph is plotted above
plt.subplot(411)
plt.plot(ts_data_2_log, label='Original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)

plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)

plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
# graph the residuals
decompose = residual
decompose.dropna(inplace=True)
test_stationarity(decompose)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.049973
# p-value                          0.030484
# #Lags Used                      14.000000
# Number of Observations Used    213.000000
# Critical Value (5%)             -2.875207
# Critical Value (1%)             -3.461429
# Critical Value (10%)            -2.574054
# dtype: float64

# %% [markdown]
# #### -3.049973 < -2.875207, the best result so far! 95% or more confident that the series is stationary

# %%
# try decomposition one more time with (ts_data_2_log - weighted_diff) to see if I can get > 1% confidence

decomposition2 = seasonal_decompose(ts_data_2_log - weighted_diff).resid
decomposition2.dropna(inplace=True)
test_stationarity(decomposition2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.519472
# p-value                          0.007501
# #Lags Used                      14.000000
# Number of Observations Used    213.000000
# Critical Value (5%)             -2.875207
# Critical Value (1%)             -3.461429
# Critical Value (10%)            -2.574054
# dtype: float64

# %% [markdown]
# #### -3.519472 < -3.461429, so my suspicions were correct!
# #### the decomposition2 series is what we should use for modeling as its more that 99% stationary

# %% [markdown]
# #### Forecast Model using ARIMA (Auto-Regressive Integrated Moving Averages)

# %%
from statsmodels.tsa.stattools import acf, pacf

# %%
lag_acf = acf(decomposition2, nlags=20)
lag_pacf = pacf(decomposition2, nlags=20, method='ols')

# %%
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(decomposition2)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(decomposition2)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

# %%
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(decomposition2)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(decomposition2)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
# okay so the purpose of those graphs are to find out the optimal lag values for generating the ARIMA model.
# looking at the graphs, the optimal values are:  pacf=p=2, acf=q=11
from statsmodels.tsa.arima_model import ARIMA
# http://statsmodels.sourceforge.net/0.6.0/generated/statsmodels.tsa.arima_model.ARIMA.html

# %% [markdown]
# #### 3 different models based on order forthcoming
#
# The (p,d,q) order of the model for the number of AR parameters, differences, and MA parameters to use.

# %% [markdown]
# #### AR Model

# %%
# the only thing that'll change is order
model = ARIMA(ts_data_2_log, order=(2, 1, 0))
results_AR = model.fit(disp=-1)  
plt.plot(decomposition2)
plt.plot(results_AR.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-decomposition2)**2))

# %% [markdown]
# #### MA Model

# %%
# the only thing that'll change is order
model = ARIMA(ts_data_2_log, order=(0, 1, 1))  
results_AR = model.fit(disp=-1)  
plt.plot(decomposition2)
plt.plot(results_AR.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-decomposition2)**2))

# %% [markdown]
# #### Combined Model

# %%
model = ARIMA(ts_data_2_log, order=(2, 1, 2))  
results_ARIMA = model.fit(disp=-1)  
plt.plot(decomposition2)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-decomposition2)**2))

# %%
lag_acf = acf(decompose, nlags=24)
lag_pacf = pacf(decompose, nlags=24, method='ols')

plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(decompose)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(decompose)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(decompose)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(decompose)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
# looks like with my 95% series, I get the same values as my 99% series. kind of expected that,
# but was definitely hoping to see more differences to draw comparisons
